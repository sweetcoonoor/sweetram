# %%
import pandas as pd
import json
import glob

# %%
path="https://raw.githubusercontent.com/sweetcoonoor/sweetram/master/1981.txt"

# %%
ff=open("1980.txt","r")
Movies=ff.read()
comma=Movies.replace("}","},")
newc=comma[:-2]
sqaureAdd="["+newc+"]"
aaa=sqaureAdd.replace("\n","")
jj=aaa.replace("ObjectId(","").replace("\")","\"")
fin=json.loads(jj)
df = pd.DataFrame.from_dict(fin, orient='columns')

# %%
cols=df.columns
dfFin=pd.DataFrame(columns=cols)
cols=df.columns
dfFin=pd.DataFrame(columns=cols)
dfFin
dfFin2=dfFin

# %%
all_files = glob.glob("*.txt")

print((all_files))
count=0
for files in all_files:
  try:
    ff=open(files,"r",encoding='utf-16')
    stringg=ff.read()
    comma=Movies.replace("}","},")
    newc=comma[:-2]
    sqaureAdd="["+newc+"]"
    aaa=sqaureAdd.replace("\n","")
    jj=aaa.replace("ObjectId(","").replace("\")","\"")
    fin=json.loads(jj)
    df = pd.DataFrame.from_dict(fin, orient='columns')
    dfFin=pd.concat([dfFin,df])
  except:
    ff=open(files,"r",encoding='utf-8')
    stringg=ff.read()
    comma=Movies.replace("}","},")
    newc=comma[:-2]
    sqaureAdd="["+newc+"]"
    aaa=sqaureAdd.replace("\n","")
    jj=aaa.replace("ObjectId(","").replace("\")","\"")
    fin=json.loads(jj)
    df = pd.DataFrame.from_dict(fin, orient='columns')
    dfFin=pd.concat([dfFin,df])
# Out:
# ['1998.txt', '1989.txt', '2004.txt', '1999.txt', '2009.txt', '2006.txt', '2002.txt', '1995.txt', '1997.txt', '1983.txt', '2000.txt', '1982.txt', '1981.txt', '1990.txt', '1987.txt', '2012.txt', '1986.txt', '2007.txt', '2001.txt', '1984.txt', '2008.txt', '1994.txt', '1992.txt', '2015.txt', '2011.txt', '1988.txt', '1991.txt', '1980.txt', '2013.txt', '2014.txt', '2005.txt', '2003.txt', '2010.txt', '1996.txt']

# %%
Movie_data=pd.concat([dfFin,dfFin2])
Movie_data.head()
# Out:
#                                               Actors  ... imdbVotes
# 0  Mark Hamill, Harrison Ford, Carrie Fisher, Bil...  ...   799,579
# 1  Gene Wilder, Richard Pryor, Georg Stanford Bro...  ...    17,705
# 2  Kareem Abdul-Jabbar, Lloyd Bridges, Peter Grav...  ...   154,994
# 3  Clint Eastwood, Sondra Locke, Geoffrey Lewis, ...  ...    12,639
# 4  Goldie Hawn, Eileen Brennan, Armand Assante, R...  ...    17,591
#
# [5 rows x 20 columns]

# %% [markdown]
# Data Exploration and Pre-processing

# %%
Genre = Movie_data['Genre']
Genre
Movie_data['imdbID']
# Out:
# 0     tt0080684
# 1     tt0081562
# 2     tt0080339
# 3     tt0080377
# 4     tt0081375
# 5     tt0080549
# 6     tt0081529
# 7     tt0080453
# 8     tt0080455
# 9     tt0081283
# 10    tt0081353
# 11    tt0081696
# 12    tt0081505
# 13    tt0081480
# 14    tt0080520
# 15    tt0080487
# 16    tt0080474
# 17    tt0081060
# 18    tt0080661
# 19    tt0080948
# 20    tt0080745
# 21    tt0080678
# 22    tt0080472
# 23    tt0081398
# 24    tt0081777
# 25    tt0080365
# 26    tt0081207
# 27    tt0080749
# 28    tt0080360
# 29    tt0080569
#         ...
# 67    tt0080850
# 68    tt0080550
# 69    tt0081758
# 70    tt0081150
# 71    tt0081433
# 72    tt0080798
# 73    tt0080979
# 74    tt0081414
# 75    tt0080868
# 76    tt0081747
# 77    tt0080855
# 78    tt0081159
# 79    tt0081080
# 80    tt0080913
# 81    tt0080442
# 82    tt0080790
# 83    tt0081759
# 84    tt0080975
# 85    tt0080461
# 86    tt0080500
# 87    tt0081753
# 88    tt0081235
# 89    tt0080854
# 90    tt0081280
# 91    tt0081625
# 92    tt0081528
# 93    tt0081044
# 94    tt0079302
# 95    tt0081334
# 96    tt0080469
# Name: imdbID, Length: 3492, dtype: object

# %%
len(Movie_data)
# Out:
# 3492

# %%
def genre_count(df, label_dict):
    max_genre = 0
    for label in Movie_data['Genre']:
        occurrences = len(Movie_data['Genre'].str.contains(label))
        print(label, occurrences)
        if occurrences > max_genre:
            max_genre = occurrences
    return max_genre

# %%
max_genre = genre_count(Genre, label_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-75223ad5231a> in <module>()
# ----> 1 max_genre = genre_count(Genre, label_dict)
#
# NameError: name 'label_dict' is not defined

# %%
#adding links with the imdbid
Movie_data['imdb_link'] = ["https://www.imdb.com/title/"+str(x) for x in Movie_data['imdbID']]
Movie_data['imdb_link']

# %%
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-51-667256a2598d> in <module>()
#       3 # extract genres
#       4 for i in Movie_data['Genre']:
# ----> 5   genres.append(list(json.loads(i).values()))
#       6
#       7 # add to 'movies' dataframe
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /usr/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /usr/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
#Webscrapping scrapping the web to indentify the posters and links
imdbURLS = Movie_data['imdb_link'].tolist()
imdbIDS = Movie_data['imdbID'].tolist()
records = [] 
counter = 0

for x in tqdm(imdbURLS): 
    # web scraping
    imdbID = imdbIDS[counter]
    r = requests.get(x)
    soup = BeautifulSoup(r.text, 'html.parser')  
    results = soup.find_all('div', attrs={'class':'poster'})  
    if results:
        first_result = results[0]  
        postername = first_result.find('img')['alt'] 
        imgurl = first_result.find('img')['src'] 
        records.append((x, postername, imgurl))
    else:
        movie = movie[movie.imdb_id != imdbID]    
counter += 1

# %%
poster_df = pd.DataFrame(records, columns=['imdb_link', 'postername', 'poster_link'])
poster_df
# Out:
#                                  imdb_link  ...                                        poster_link
# 0     https://www.imdb.com/title/tt0080684  ...  https://m.media-amazon.com/images/M/MV5BYmU1ND...
# 1     https://www.imdb.com/title/tt0081562  ...  https://m.media-amazon.com/images/M/MV5BMmFkM2...
# 2     https://www.imdb.com/title/tt0080339  ...  https://m.media-amazon.com/images/M/MV5BZjA3Yj...
# 3     https://www.imdb.com/title/tt0080377  ...  https://m.media-amazon.com/images/M/MV5BOTUzYm...
# 4     https://www.imdb.com/title/tt0081375  ...  https://m.media-amazon.com/images/M/MV5BMjIyNj...
# 5     https://www.imdb.com/title/tt0080549  ...  https://m.media-amazon.com/images/M/MV5BNzg1ZD...
# 6     https://www.imdb.com/title/tt0081529  ...  https://m.media-amazon.com/images/M/MV5BYmFhMG...
# 7     https://www.imdb.com/title/tt0080453  ...  https://m.media-amazon.com/images/M/MV5BOWU2ZD...
# 8     https://www.imdb.com/title/tt0080455  ...  https://m.media-amazon.com/images/M/MV5BYTdlMD...
# 9     https://www.imdb.com/title/tt0081283  ...  https://m.media-amazon.com/images/M/MV5BNWU3MD...
# 10    https://www.imdb.com/title/tt0081353  ...  https://m.media-amazon.com/images/M/MV5BMDgyND...
# 11    https://www.imdb.com/title/tt0081696  ...  https://m.media-amazon.com/images/M/MV5BNDFlND...
# 12    https://www.imdb.com/title/tt0081505  ...  https://m.media-amazon.com/images/M/MV5BZWFlYm...
# 13    https://www.imdb.com/title/tt0081480  ...  https://m.media-amazon.com/images/M/MV5BYWRiY2...
# 14    https://www.imdb.com/title/tt0080520  ...  https://m.media-amazon.com/images/M/MV5BODk3Ym...
# 15    https://www.imdb.com/title/tt0080487  ...  https://m.media-amazon.com/images/M/MV5BY2I1NW...
# 16    https://www.imdb.com/title/tt0080474  ...  https://m.media-amazon.com/images/M/MV5BYzViZj...
# 17    https://www.imdb.com/title/tt0081060  ...  https://m.media-amazon.com/images/M/MV5BZWVmMm...
# 18    https://www.imdb.com/title/tt0080661  ...  https://m.media-amazon.com/images/M/MV5BN2Q2Mz...
# 19    https://www.imdb.com/title/tt0080948  ...  https://m.media-amazon.com/images/M/MV5BZGEwNT...
# 20    https://www.imdb.com/title/tt0080745  ...  https://m.media-amazon.com/images/M/MV5BN2Y4ZD...
# 21    https://www.imdb.com/title/tt0080678  ...  https://m.media-amazon.com/images/M/MV5BMDVjNj...
# 22    https://www.imdb.com/title/tt0080472  ...  https://m.media-amazon.com/images/M/MV5BODg3MG...
# 23    https://www.imdb.com/title/tt0081398  ...  https://m.media-amazon.com/images/M/MV5BYjRmOD...
# 24    https://www.imdb.com/title/tt0081777  ...  https://m.media-amazon.com/images/M/MV5BYTlkNW...
# 25    https://www.imdb.com/title/tt0080365  ...  https://m.media-amazon.com/images/M/MV5BYzJkZj...
# 26    https://www.imdb.com/title/tt0081207  ...  https://m.media-amazon.com/images/M/MV5BYzQ3Ym...
# 27    https://www.imdb.com/title/tt0080749  ...  https://m.media-amazon.com/images/M/MV5BNmMwMW...
# 28    https://www.imdb.com/title/tt0080360  ...  https://m.media-amazon.com/images/M/MV5BZTdkOT...
# 29    https://www.imdb.com/title/tt0080569  ...  https://m.media-amazon.com/images/M/MV5BYjFmOD...
# ...                                    ...  ...                                                ...
# 3182  https://www.imdb.com/title/tt0081159  ...  https://m.media-amazon.com/images/M/MV5BMGQ5OD...
# 3183  https://www.imdb.com/title/tt0081080  ...  https://m.media-amazon.com/images/M/MV5BODM4Mj...
# 3184  https://www.imdb.com/title/tt0080913  ...  https://m.media-amazon.com/images/M/MV5BMTkxMj...
# 3185  https://www.imdb.com/title/tt0080442  ...  https://m.media-amazon.com/images/M/MV5BNGU3Yz...
# 3186  https://www.imdb.com/title/tt0080790  ...  https://m.media-amazon.com/images/M/MV5BOTI1NT...
# 3187  https://www.imdb.com/title/tt0081759  ...  https://m.media-amazon.com/images/M/MV5BYTQ4Zj...
# 3188  https://www.imdb.com/title/tt0080975  ...  https://m.media-amazon.com/images/M/MV5BODdjYT...
# 3189  https://www.imdb.com/title/tt0080461  ...  https://m.media-amazon.com/images/M/MV5BYWZkMT...
# 3190  https://www.imdb.com/title/tt0080500  ...  https://m.media-amazon.com/images/M/MV5BODExYz...
# 3191  https://www.imdb.com/title/tt0081753  ...  https://m.media-amazon.com/images/M/MV5BODI2Mm...
# 3192  https://www.imdb.com/title/tt0081235  ...  https://m.media-amazon.com/images/M/MV5BMWJjY2...
# 3193  https://www.imdb.com/title/tt0080854  ...  https://m.media-amazon.com/images/M/MV5BZTY2Yj...
# 3194  https://www.imdb.com/title/tt0081280  ...  https://m.media-amazon.com/images/M/MV5BMTQxOT...
# 3195  https://www.imdb.com/title/tt0081625  ...  https://m.media-amazon.com/images/M/MV5BMDU3ND...
# 3196  https://www.imdb.com/title/tt0081528  ...  https://m.media-amazon.com/images/M/MV5BN2Y1Mm...
# 3197  https://www.imdb.com/title/tt0081044  ...  https://m.media-amazon.com/images/M/MV5BMzI2Ym...
# 3198  https://www.imdb.com/title/tt0079302  ...  https://m.media-amazon.com/images/M/MV5BM2VkND...
# 3199  https://www.imdb.com/title/tt0081334  ...  https://m.media-amazon.com/images/M/MV5BNzVjND...
# 3200  https://www.imdb.com/title/tt0080469  ...  https://m.media-amazon.com/images/M/MV5BNTI0OD...
# 3201  https://www.imdb.com/title/tt0080684  ...  https://m.media-amazon.com/images/M/MV5BYmU1ND...
# 3202  https://www.imdb.com/title/tt0081562  ...  https://m.media-amazon.com/images/M/MV5BMmFkM2...
# 3203  https://www.imdb.com/title/tt0080339  ...  https://m.media-amazon.com/images/M/MV5BZjA3Yj...
# 3204  https://www.imdb.com/title/tt0080377  ...  https://m.media-amazon.com/images/M/MV5BOTUzYm...
# 3205  https://www.imdb.com/title/tt0081375  ...  https://m.media-amazon.com/images/M/MV5BMjIyNj...
# 3206  https://www.imdb.com/title/tt0080549  ...  https://m.media-amazon.com/images/M/MV5BNzg1ZD...
# 3207  https://www.imdb.com/title/tt0081529  ...  https://m.media-amazon.com/images/M/MV5BYmFhMG...
# 3208  https://www.imdb.com/title/tt0080453  ...  https://m.media-amazon.com/images/M/MV5BOWU2ZD...
# 3209  https://www.imdb.com/title/tt0080455  ...  https://m.media-amazon.com/images/M/MV5BYTdlMD...
# 3210  https://www.imdb.com/title/tt0081283  ...  https://m.media-amazon.com/images/M/MV5BNWU3MD...
# 3211  https://www.imdb.com/title/tt0081353  ...  https://m.media-amazon.com/images/M/MV5BMDgyND...
#
# [3212 rows x 3 columns]

# %%
df_movietotal = pd.merge(Movie_data, poster_df, on='imdb_link')

# %%
df_movietotal.to_csv('movie_metadataWithPoster.csv', sep='\t')

# %%
#Poster Image Processing , storing in the dictionary
import scipy.misc
image_glob = glob.glob("*.jpg")
images = {}
for images in image_glob:
    img_dict[get_id(fn)] = scipy.misc.imread(fn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-2cb249f4218e> in <module>()
#       3 images = {}
#       4 for images in image_glob:
# ----> 5     img_dict[get_id(fn)] = scipy.misc.imread(fn)
#       6
#
# AttributeError: module 'scipy.misc' has no attribute 'imread'

# %%
import matplotlib.pyplot as plt
def show_img(id):
    title = Movie_data[Movie_data['imdbID'] == id]["Title"].values[0]
    print(title)
    genre = Movie_data[Movie_data['imdbID'] == id]["Genre"].values[0]
    plt.imshow(img_dict[id])
    plt.title("{} \n {}".format(title, genre))

# %%
show_img("tt0080684")
# Out:
# Star Wars: Episode V - The Empire Strikes Back
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-3b8b0f3eb60e> in <module>()
# ----> 1 show_img("tt0080684")
#
# <ipython-input-111-fdbd1f57ba6b> in show_img(id)
#       4     print(title)
#       5     genre = Movie_data[Movie_data['imdbID'] == id]["Genre"].values[0]
# ----> 6     plt.imshow(img_dict[id])
#       7     plt.title("{} \n {}".format(title, genre))
#
# KeyError: 'tt0080684'

# %%
for fn in image_glob:
    try:
        img_dict[get_id(fn)] = imageio.imread(fn)
    except:
        pass

# %%
def show_img(id):
    title = df_movietotal[df_movietotal["imdb_id"] == id]["original_title"].values[0]
    genre = df_movietotal[df_movietotal["imdb_id"] == id]["genres"].values[0]
    plt.imshow(img_dict[id])
    plt.title("{} \n {}".format(title, genre))

# %%
title =df_movietotal["imdb_id"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'imdb_id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-5c27b4c9e29f> in <module>()
# ----> 1 title =df_movietotal["imdb_id"]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'imdb_id'

# %%
#Preparing Dataset

def preprocess(img, size=(150, 101)):
    img = scipy.misc.imresize(img, size)
    img = img.astype(np.float32)
    img = (img / 127.5) - 1.
    return img

# %%
def prepare_data(data, img_dict, size=(150, 101)):
    print("Generation dataset...")
    dataset = []
    y = []
    ids = []
    label_dict = {"word2idx": {}, "idx2word": []}
    idx = 0
    genre_per_movie = data["Genre"].apply(lambda x: str(x).split("|"))
    for l in [g for d in genre_per_movie for g in d]:
        if l in label_dict["idx2word"]:
            pass
        else:
            label_dict["idx2word"].append(l)
            label_dict["word2idx"][l] = idx
            idx += 1
    n_classes = len(label_dict["idx2word"])
    print("identified {} classes".format(n_classes))
    n_samples = len(img_dict)
    print("got {} samples".format(n_samples))
    for k in img_dict:
        try:
            g = data[data["imdbId"] == int(k)]["Genre"].values[0].split("|")
            img = preprocess(img_dict[k], size)
            if img.shape != (150, 101, 3):
                continue
            l = np.sum([np.eye(n_classes, dtype="uint8")[label_dict["word2idx"][s]] 
                                                        for s in g], axis=0)
            y.append(l)
            dataset.append(img)
            ids.append(k)
        except:
            pass
    print("DONE")
    return dataset, y, label_dict, ids
